# %% [markdown]
# # 1. ANN 과제

# %% [markdown]
# ## Backpropagation의 가중치 업데이트
#
# 다음은 17페이지에 제시된 **역전파(Backpropagation) 과정 중 가중치 업데이트 단계**를 나타낸 식이다.
#
# 가중치 업데이트 단계는 앞선 단계에서 계산된 오차의 기울기를 이용해
# 손실 함수(Error)를 최소화하는 방향으로 가중치를 조정하는 과정이며,
# 이때 사용되는 규칙은 대표적인 **최적화 기법**에 해당한다.
#
#
# $$
# W^{(l)} \leftarrow W^{(l)} - \alpha \frac{\partial E}{\partial W^{(l)}}
# $$
#
#
# ##  문제
#
# 1. 위 가중치 업데이트 식이 의미하는 **최적화 기법**이 무엇인지 설명하시오.
# 2. 위 식에서
# $$
# \frac{\partial E}{\partial W^{(l)}}
# $$
#    가 어떻게 계산되는지를 **Chain Rule(연쇄법칙)** 을 이용해 설명하시오.
#
#    (Hint: 세션 자료 하단에 제시된 최종 결과식을 참고헤 도출 과정 서술하면 됨)

# %% [markdown]
# ### 답변 1 :
# 위의 업데이트 식이 의미하는 최적화 기법은 경사 하강법이다. 경사 하강법은 현재 가중치를 기준으로 기울기를 구한 후 그 기울기의 반대 방향으로 가중치를 이동시켜 최적의 파라미터를 찾는 기법을 말한다.
#
# ### 답변 2 :
# 먼저 현재 모델의 예측값과 실제 정답을 비교하여 발생한 오차를 구한다. 이때 출력층의 뉴런이 최종 오차에 기여한 정도를 델타라고 정의한다.
# 델타를 출력층에서 입력층 방향으로 이동시키는 역전파를 진행하는 과정에서 연쇄법칙을 적용한다.
# 역전파 과정에서 델타 값은 다음층에서 넘어온 오차 신호와 연결된 가중치, 활성화 함수의 미분값을 통해 계산된다.
# 이러한 과정을 통해 계산된 현재층의 오차 신호에 해당 층으로 전달된 입력값을 곱해주면 가중치 미분값을 알 수 있다.

# %% [markdown]
# ---

# %% [markdown]
# # 2. DNN 과제

# %% [markdown]
# 다음은 세션 자료 25p의 과제의 내용이다. 자료에 주어진 조건을 바탕으로 아래 문제들을 해결하시오.
#
# ---
#
# ### **1. 파라미터 수 직접 계산하기**
# 주어진 신경망 구조(784 - 16 - 16 - 10)를 기준으로 총 학습 파라미터 수(가중치 $W$ 및 편향 $b$)를 직접 계산하시오.

# %% [markdown]
# ### 답변 :
# Layer 1 : 784 x 16 (가중치) + 1 x 16 (편향) = 12544 + 16 = 12560
# Layer 2 : 16 x 16 (가중치) + 1 x 16 (편향) = 256 + 16 = 272
# Layer 3 : 16 x 10 (가중치) + 1 x 10 (편향) = 160 + 10 = 170
# Total : 12560 + 272 + 170 = 13002

# %% [markdown]
# ---
#
# ### **2. TensorFlow 모델 구현 및 검증**
# 동일한 구조의 DNN을 TensorFlow/Keras 코드로 구현하고, `model.summary()` 출력 결과와 위에서 계산한 값이 일치하는지 확인하시오. (학습 과정은 필요 X)

# %%
# !python3 -m pip install --upgrade pip
# !python3 -m pip install tensorflow
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# Requirement already satisfied: tensorflow in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/subin/Library/Python/3.13/lib/python/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (80.10.1)
# Requirement already satisfied: six>=1.12.0 in /Users/subin/Library/Python/3.13/lib/python/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (3.13.1)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: h5py>=3.11.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/subin/Library/Python/3.13/lib/python/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
## 1. 적절한 라이브러리를 import하세요
import tensorflow as tf
from tensorflow.keras import layers, models

## 2. 모델 설계하기
model = models.Sequential([
    layers.Dense(16, activation='relu', input_shape = (784,)),
    layers.Dense(16, activation='relu'),
    layers.Dense(10, activation='softmax')
])

## 3. 모델 summary 출력
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_33 (Dense)                │ (None, 16)             │        12,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 10)             │           170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,002 (50.79 KB)
#  Trainable params: 13,002 (50.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ---
#
# ### **3. 결과 비교**
# 1번에서 직접 계산한 학습 파라미터 수와 model.summary() 출력 결과의 Total params 값이
# 서로 일치하는지 확인하시오.

# %% [markdown]
# ### 답변 :
# 1번에서 직접 계산한 학습 파라미터 수 : 13002
# 2번에서 출력한 model.summary()의 Total params : 13002
# 두 값은 서로 일치한다.

# %% [markdown]
# # 3. CNN 과제

# %% [markdown]
# ---
# ## **Introduction**
#
# ![](https://miro.medium.com/v2/resize:fit:3744/format:webp/1*SGPGG7oeSvVlV5sOSQ2iZw.png)
# ([Image Credit](https://medium.com/data-science/mnist-handwritten-digits-classification-using-a-convolutional-neural-network-cnn-af5fafbc35e9))
#
# Pytorch를 사용하여 이미지와 같이 MNIST 데이터셋을 분류하는 CNN 모델을 구현해봅시다.
# Pytorch가 익숙하지 않은 분들은 [다음 튜토리얼](https://docs.pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html)을 참고해주세요.

# %% [markdown]
# ---
# ## **1. Import Libraries & Data**

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.9.1)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.24.1)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch) (80.10.1)
# Requirement already satisfied: sympy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torch) (2026.1.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torchvision) (2.4.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from torchvision) (12.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)

# %%
# !pip install matplotlib numpy
# Out:
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.10.8)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/subin/Library/Python/3.13/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/subin/Library/Python/3.13/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/subin/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# 필요한 라이브러리를 불러옵니다.
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
import numpy as np

# %%
import ssl
import urllib.request

# SSL 인증서 검사를 아예 수행하지 않도록 전역 설정
ssl._create_default_https_context = ssl._create_unverified_context
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)

# 그다음 기존의 다운로드 코드를 실행하세요
trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# 이 아래에 기존 코드를 실행하세요
trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

# %%
# 이미지 변환 함수를 정의합니다.
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)) ## 1. 이미지에 Normalize를 하는 이유와 2. 다음과 같은 숫자를 사용한 이유는 무엇일까요? (답은 작성하지 않으셔도 됩니다.)
])

# 데이터셋을 불러오고, DataLoader를 사용하여 데이터를 로드합니다.
trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

# %%
## 데이터셋의 크기와 차원을 확인합니다.
print(f'training set size: {len(trainset)}')
print(f'test set size: {len(testset)}\n')

print(f'training set dimension: {trainset.data.shape}')
print(f'test set dimension: {testset.data.shape}')
# Out:
# training set size: 60000
# test set size: 10000
#
# training set dimension: torch.Size([60000, 28, 28])
# test set dimension: torch.Size([10000, 28, 28])

# %% [markdown]
# ---
# ## **2. Define a Convolutional Neural Network**

# %% [markdown]
# 주어진 모델을 다시 한 번 정리해봅시다.
#
#
# **Conv_1** : 3x3 filter 32개, stride: 1, padding: 1, activation = 'relu'
# **Pool_2** : 2x2 filter, stride: 2, padding: 0
# **Conv_3** : 3x3 filter 64개, stride: 1, padding: 1, activation = 'relu'
# **Pool_4** : 2x2 filter, stride: 2, padding: 0
# **Dense_5** : 128, activation = 'relu'
# **Dense_6** : 10, activation = 'softmax'

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# 아래 코드의 빈칸을 채워주세요!
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2)
        self.dense5 = nn.Linear(64 * 7 * 7, 128)
        self.dense6 = nn.Linear(128, 10)

    def forward(self, x): #주어진 모델을 다시 한 번 정리해봅시다.
        x = F.relu(self.conv1(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.pool4(x)
        x = torch.flatten(x, 1) # flatten layer: 2D -> 1D
        x = F.relu(self.dense5(x))
        x = self.dense6(x)
        return x

cnn = CNN()
print(cnn)
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dense5): Linear(in_features=3136, out_features=128, bias=True)
#   (dense6): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2)
        self.dense5 = nn.Linear(64 * 7 * 7, 128)
        self.dense6 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.pool4(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.dense5(x))
        x = self.dense6(x)
        return x

cnn = CNN()
print(cnn)
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dense5): Linear(in_features=3136, out_features=128, bias=True)
#   (dense6): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# #### **문제: 주어진 모델에 대해, layer마다 필요한 parameter의 수를 계산하세요.**

# %% [markdown]
# - Conv_1: (32 x 3 x 3 x 1) + 32 = 320
# - Pool_2: 0
# - Conv_3: (64 x 32 x 3 x 3) + 64 = 18496
# - Pool_4: 0
# - FC_5: (3136(7x7x64) x 128) + 128 = 401536
# - FC_6: (128 x 10) + 10 = 1290

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.5.1)

# %%
# summary를 사용하여 정답과 계산 결과가 일치하는지 확인하세요.
# !pip install torchsummary

from torchsummary import summary

summary(cnn, (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 28, 28]             320
#          MaxPool2d-2           [-1, 32, 14, 14]               0
#             Conv2d-3           [-1, 64, 14, 14]          18,496
#          MaxPool2d-4             [-1, 64, 7, 7]               0
#             Linear-5                  [-1, 128]         401,536
#             Linear-6                   [-1, 10]           1,290
# ================================================================
# Total params: 421,642
# Trainable params: 421,642
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.36
# Params size (MB): 1.61
# Estimated Total Size (MB): 1.97
# ----------------------------------------------------------------

# %% [markdown]
# ---
# ## **3. Train a model**

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn.parameters(), lr=0.001)

# %%
for epoch in range(3):

    running_loss = 0
    acc = 0

    # training loop
    cnn.train()
    for i, data in enumerate(trainloader):
        inputs, labels = data

        # parameter gradient 초기화
        optimizer.zero_grad()

        outputs = cnn(inputs) # 모델을 통해 output 계산
        loss = criterion(outputs, labels) # loss 계산
        loss.backward() # gradient 계산 (backpropagation)
        optimizer.step() # parameter 업데이트

        running_loss += loss.item()
        if i % 100 == 99:
            print(f'[Epoch: {epoch + 1}, {i + 1:3d}] loss: {running_loss / 100:.3f}')
            running_loss = 0

    # testing loop
    cnn.eval()
    for i, data in enumerate(testloader):
        inputs, labels = data
        outputs = cnn(inputs)
        _, predicted = torch.max(outputs.data, 1)
        acc += (predicted == labels).sum().item()
    acc = acc / len(testloader.dataset)
    print(f"====== Epoch {epoch + 1} Finished, Accuracy: {acc*100:.2f}% ======")

print(f"\nTraining finished. Final accuracy: {acc*100:.2f}%")
# Out:
# [Epoch: 1, 100] loss: 0.585
# [Epoch: 1, 200] loss: 0.160
# [Epoch: 1, 300] loss: 0.112
# [Epoch: 1, 400] loss: 0.094
# [Epoch: 1, 500] loss: 0.084
# [Epoch: 1, 600] loss: 0.062
# [Epoch: 1, 700] loss: 0.068
# [Epoch: 1, 800] loss: 0.061
# [Epoch: 1, 900] loss: 0.065
# ====== Epoch 1 Finished, Accuracy: 98.73% ======
# [Epoch: 2, 100] loss: 0.038
# [Epoch: 2, 200] loss: 0.040
# [Epoch: 2, 300] loss: 0.044
# [Epoch: 2, 400] loss: 0.037
# [Epoch: 2, 500] loss: 0.046
# [Epoch: 2, 600] loss: 0.042
# [Epoch: 2, 700] loss: 0.047
# [Epoch: 2, 800] loss: 0.047
# [Epoch: 2, 900] loss: 0.043
# ====== Epoch 2 Finished, Accuracy: 98.58% ======
# [Epoch: 3, 100] loss: 0.026
# [Epoch: 3, 200] loss: 0.023
# [Epoch: 3, 300] loss: 0.027
# [Epoch: 3, 400] loss: 0.030
# [Epoch: 3, 500] loss: 0.033
# [Epoch: 3, 600] loss: 0.032
# [Epoch: 3, 700] loss: 0.027
# [Epoch: 3, 800] loss: 0.035
# [Epoch: 3, 900] loss: 0.027
# ====== Epoch 3 Finished, Accuracy: 99.14% ======
#
# Training finished. Final accuracy: 99.14%

# %% [markdown]
# ---
# ## **4. Experiment with the model**

# %%
# 기존의 모델을 원하는 대로 수정해보세요!
# ex) layer 추가, kernel size 변경, optimizer 변경, activation 함수 변경, Dropout, etc.
class newCNN(nn.Module):
    def __init__(self):
        super(newCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=5, stride=1, padding=2) ##커널사이즈 증가
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool4 = nn.MaxPool2d(2, 2)
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1) ##레이어 추가
        self.dense5 = nn.Linear(128 * 7 * 7, 128)
        self.dropout = nn.Dropout(0.5) ##dropout
        self.dense6 = nn.Linear(128,10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.pool4(x)
        x = F.relu(self.conv5(x)) ## 레이어 추가
        x = torch.flatten(x, 1)
        x = F.relu(self.dense5(x))
        x = self.dropout(x)       ## dropout 추가
        x = self.dense6(x)
        return x

new_cnn = newCNN()
print(new_cnn)
# Out:
# newCNN(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (dense5): Linear(in_features=6272, out_features=128, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (dense6): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(new_cnn.parameters(), lr=0.001)

# %%
for epoch in range(3):

    running_loss = 0
    acc = 0

    # training loop
    new_cnn.train()
    for i, data in enumerate(trainloader):
        inputs, labels = data

        # parameter gradient 초기화
        optimizer.zero_grad()

        outputs = new_cnn(inputs) # 모델을 통해 output 계산
        loss = criterion(outputs, labels) # loss 계산
        loss.backward() # gradient 계산 (backpropagation)
        optimizer.step() # parameter 업데이트

        running_loss += loss.item()
        if i % 100 == 99:
            print(f'[Epoch: {epoch + 1}, {i + 1:3d}] loss: {running_loss / 100:.3f}')
            running_loss = 0

    # testing loop
    new_cnn.eval()
    for i, data in enumerate(testloader):
        inputs, labels = data
        outputs = new_cnn(inputs)
        _, predicted = torch.max(outputs.data, 1)
        acc += (predicted == labels).sum().item()
    acc = acc / len(testloader.dataset)
    print(f"====== Epoch {epoch + 1} Finished, Accuracy: {acc*100:.2f}% ======")

print(f"\nTraining finished. Final accuracy: {acc*100:.2f}%")
# Out:
# [Epoch: 1, 100] loss: 0.766
# [Epoch: 1, 200] loss: 0.236
# [Epoch: 1, 300] loss: 0.153
# [Epoch: 1, 400] loss: 0.129
# [Epoch: 1, 500] loss: 0.116
# [Epoch: 1, 600] loss: 0.116
# [Epoch: 1, 700] loss: 0.098
# [Epoch: 1, 800] loss: 0.103
# [Epoch: 1, 900] loss: 0.092
# ====== Epoch 1 Finished, Accuracy: 98.85% ======
# [Epoch: 2, 100] loss: 0.072
# [Epoch: 2, 200] loss: 0.082
# [Epoch: 2, 300] loss: 0.071
# [Epoch: 2, 400] loss: 0.068
# [Epoch: 2, 500] loss: 0.070
# [Epoch: 2, 600] loss: 0.064
# [Epoch: 2, 700] loss: 0.058
# [Epoch: 2, 800] loss: 0.059
# [Epoch: 2, 900] loss: 0.067
# ====== Epoch 2 Finished, Accuracy: 99.05% ======
# [Epoch: 3, 100] loss: 0.040
# [Epoch: 3, 200] loss: 0.055
# [Epoch: 3, 300] loss: 0.059
# [Epoch: 3, 400] loss: 0.053
# [Epoch: 3, 500] loss: 0.053
# [Epoch: 3, 600] loss: 0.045
# [Epoch: 3, 700] loss: 0.041
# [Epoch: 3, 800] loss: 0.057
# [Epoch: 3, 900] loss: 0.042
# ====== Epoch 3 Finished, Accuracy: 99.21% ======
#
# Training finished. Final accuracy: 99.21%

# %% [markdown]
# ### **기존의 모델에서 어떤 부분을 수정하였는지 설명해주세요.**
#
# 답변 :
# 1. conv1의 커널의 크기를 기존 3x3의 크기에서 5x5로 키워 이미지의 초기 특징을 어 넓은 영역으로 수용할 수 있도록 한다.
# 2. conv5라는 계층을 추가하여 모델의 깊이를 화장시켰다.
# 3. drop out 레이어를 도입하여, 학습을 진행할 때 뉴런의 절반을 무작위로 제외하도록 하였다.

# %% [markdown]
# ### **이러한 변경 사항이 결과에 어떻게 영향을 미쳤나요?**
#
# 답변 :
# 1. conv1의 커널의 크기를 증가시켰고, 출력 결과에 padding = (2,2)가 적용이 되었음을 확인할 수 있다.
# 2. conv5 계층 추가를 통해 in_featuresrk 6272라는 숫자가 나왔고, 7x7의 사이즈의 맵이 128개가 생성되었음을 알 수 있다. 이를 통해 7x7x128 = 6272개의 데이터를 생성되었고, 기존 모델보다 2배 많은 특징 데이터를 생성하게 되었다.
# 3. drop out (0.5)를 통해서 6272개의 특징 데이터 중 절반을 무작위로 삭제했고, 과적합을 차단했음을 알 수 있다.

# %% [markdown]
# ---
# ## **5. (정말 마지막) 이론 문제**
# convolution이 무엇인지, 그리고 이를 이용하면 이미지의 feature를 추출할 수 있음을 이해하기 위한 문제입니다.
#
# 다음과 같은 input과 kernel이 존재할 때, 발표 자료의 방식과 같이 feature map을 구하고, 그 결과를 ?에 적으시오.
# ![](https://i.imgur.com/v1wkvhW.png)

# %% [markdown]
# 정답:
# 1 0
# 0 1
#
# 1행 1열 : Input 0 0 / 0 1 & Kernel 1 0 / 0 1 - 1
# 1행 2열 : Input 0 1 / 1 0 & Kernel 1 0 / 0 1 - 0
# 2행 1열 : Input 0 1 / 1 0 & Kernel 1 0 / 0 1 - 0
# 2행 2열 : Input 1 0 / 0 0 & Kernel 1 0 / 0 1 - 1
